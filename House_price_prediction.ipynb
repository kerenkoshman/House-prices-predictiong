# %% [markdown]
# <a href="https://colab.research.google.com/github/kerenkoshman/House-prices-predictiong/blob/master/House_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.animation as animation # import animation support
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
#  generation some house sizes between 1000 and 3500 (typical sq ft of house)
num_house = 160
np.random.seed(42)
house_size = np.random.randint(low=1000, high=3500, size=num_house )

# Generate house prices from house size with a random noise added.
np.random.seed(42)
house_price = house_size * 100.0 + np.random.randint(low=20000, high=70000, size=num_house)

# %%
# Plot generated house and size 
plt.plot(house_size, house_price, "bx")  # bx = blue x
plt.ylabel("Price")
plt.xlabel("Size")
plt.show()

# %%
# normalize function
def normalize(array):
    return (array - array.mean()) / array.std()

# %%
# define number of training samples, 0.7 = 70%.  We can take the first 70% since the values are randomized
num_train_samples = math.floor(num_house * 0.7)

# %%
# define training data
train_house_size = np.asarray(house_size[:num_train_samples])
train_price = np.asanyarray(house_price[:num_train_samples:])

train_house_size_norm = normalize(train_house_size)
train_price_norm = normalize(train_price)

# %%
# define test data
test_house_size = np.array(house_size[num_train_samples:])
test_house_price = np.array(house_price[num_train_samples:])

test_house_size_norm = normalize(test_house_size)
test_house_price_norm = normalize(test_house_price)

# %%
#  Set up the TensorFlow placeholders that get updated as we descend down the gradient
tf_house_size = tf.placeholder("float", name="house_size")
tf_price = tf.placeholder("float", name="price")

# %%
# Define the variables holding the size_factor and price we set during training.  
# We initialize them to some random values based on the normal distribution.
tf_size_factor = tf.Variable(np.random.randn(), name="size_factor")
tf_price_offset = tf.Variable(np.random.randn(), name="price_offset")

# %%
# 2. Define the operations for the predicting values - predicted price = (size_factor * house_size ) + price_offset
#  Notice, the use of the tensorflow add and multiply functions.  These add the operations to the computation graph,
#  AND the tensorflow methods understand how to deal with Tensors.  Therefore do not try to use numpy or other library 
#  methods.
tf_price_pred = tf.add(tf.multiply(tf_size_factor, tf_house_size), tf_price_offset)

# %%
# 3. Define the Loss Function (how much error) - Mean squared error
tf_cost = tf.reduce_sum(tf.pow(tf_price_pred-tf_price, 2))/(2*num_train_samples)

# %%
# Optimizer learning rate.  The size of the steps down the gradient
learning_rate = 0.1

# %%
# 4. define a Gradient descent optimizer that will minimize the loss defined in the operation "cost".
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(tf_cost)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph in the session
with tf.Session() as sess:
    sess.run(init)

    # set how often to display training progress and number of training iterations
    display_every = 2
    num_training_iter = 50

    # calculate the number of lines to animation
    fit_num_plots = math.floor(num_training_iter/display_every)
    # add storage of factor and offset values from each epoch
    fit_size_factor = np.zeros(fit_num_plots)
    fit_price_offsets = np.zeros(fit_num_plots)
    fit_plot_idx = 0    

   # keep iterating the training data
    for iteration in range(num_training_iter):

        # Fit all training data
        for (x, y) in zip(train_house_size_norm, train_price_norm):
            sess.run(optimizer, feed_dict={tf_house_size: x, tf_price: y})

        # Display current status
        if (iteration + 1) % display_every == 0:
            c = sess.run(tf_cost, feed_dict={tf_house_size: train_house_size_norm, tf_price:train_price_norm})
            print("iteration #:", '%04d' % (iteration + 1), "cost=", "{:.9f}".format(c), \
                "size_factor=", sess.run(tf_size_factor), "price_offset=", sess.run(tf_price_offset))
            # Save the fit size_factor and price_offset to allow animation of learning process
            fit_size_factor[fit_plot_idx] = sess.run(tf_size_factor)
            fit_price_offsets[fit_plot_idx] = sess.run(tf_price_offset)
            fit_plot_idx = fit_plot_idx + 1

    print("Optimization Finished!")
    training_cost = sess.run(tf_cost, feed_dict={tf_house_size: train_house_size_norm, tf_price: train_price_norm})
    print("Trained cost=", training_cost, "size_factor=", sess.run(tf_size_factor), "price_offset=", sess.run(tf_price_offset), '\n')


   # Plot of training and test data, and learned regression
    
    # get values used to normalized data so we can denormalize data back to its original scale
    train_house_size_mean = train_house_size.mean()
    train_house_size_std = train_house_size.std()

    train_price_mean = train_price.mean()
    train_price_std = train_price.std()

    # Plot the graph
    plt.rcParams["figure.figsize"] = (10,8)
    plt.figure()
    plt.ylabel("Price")
    plt.xlabel("Size (sq.ft)")
    plt.plot(train_house_size, train_price, 'go', label='Training data')
    plt.plot(test_house_size, test_house_price, 'mo', label='Testing data')
    plt.plot(train_house_size_norm * train_house_size_std + train_house_size_mean,
             (sess.run(tf_size_factor) * train_house_size_norm + sess.run(tf_price_offset)) * train_price_std + train_price_mean,
             label='Learned Regression')
 
    plt.legend(loc='upper left')
    plt.show()



    # 
    # Plot another graph that animation of how Gradient Descent sequentually adjusted size_factor and price_offset to 
    # find the values that returned the "best" fit line.
    fig, ax = plt.subplots()
    line, = ax.plot(house_size, house_price)

    plt.rcParams["figure.figsize"] = (10,8)
    plt.title("Gradient Descent Fitting Regression Line")
    plt.ylabel("Price")
    plt.xlabel("Size (sq.ft)")
    plt.plot(train_house_size, train_price, 'go', label='Training data')
    plt.plot(test_house_size, test_house_price, 'mo', label='Testing data')

    def animate(i):
        line.set_xdata(train_house_size_norm * train_house_size_std + train_house_size_mean)  # update the data
        line.set_ydata((fit_size_factor[i] * train_house_size_norm + fit_price_offsets[i]) * train_price_std + train_price_mean)  # update the data
        return line,
 
     # Init only required for blitting to give a clean slate.
    def initAnim():
        line.set_ydata(np.zeros(shape=house_price.shape[0])) # set y's to 0
        return line,

    ani = animation.FuncAnimation(fig, animate, frames=np.arange(0, fit_plot_idx), init_func=initAnim,
                                 interval=1000, blit=True)

    plt.show()
# Out:
# iteration #: 0002 cost= 0.720058978 size_factor= 0.09177997 price_offset= -0.78197587
# iteration #: 0004 cost= 0.488989919 size_factor= 0.25305912 price_offset= -0.6400547
# iteration #: 0006 cost= 0.334198892 size_factor= 0.38506958 price_offset= -0.52387947
# iteration #: 0008 cost= 0.230510592 size_factor= 0.4931228 price_offset= -0.42877954
# iteration #: 0010 cost= 0.161057383 size_factor= 0.5815667 price_offset= -0.35093102
# iteration #: 0012 cost= 0.114538930 size_factor= 0.65396035 price_offset= -0.2872049
# iteration #: 0014 cost= 0.083384469 size_factor= 0.713216 price_offset= -0.23503916
# iteration #: 0016 cost= 0.062521778 size_factor= 0.76171756 price_offset= -0.19233663
# iteration #: 0018 cost= 0.048552584 size_factor= 0.8014175 price_offset= -0.1573807
# iteration #: 0020 cost= 0.039200630 size_factor= 0.8339127 price_offset= -0.1287661
# iteration #: 0022 cost= 0.032940891 size_factor= 0.86051065 price_offset= -0.10534229
# iteration #: 0024 cost= 0.028751854 size_factor= 0.882282 price_offset= -0.08616769
# iteration #: 0026 cost= 0.025949381 size_factor= 0.90010184 price_offset= -0.07047155
# iteration #: 0028 cost= 0.024075124 size_factor= 0.9146879 price_offset= -0.05762279
# iteration #: 0030 cost= 0.022822181 size_factor= 0.92662656 price_offset= -0.04710484
# iteration #: 0032 cost= 0.021984996 size_factor= 0.9363989 price_offset= -0.038494952
# iteration #: 0034 cost= 0.021425985 size_factor= 0.9443974 price_offset= -0.031446975
# iteration #: 0036 cost= 0.021052983 size_factor= 0.9509445 price_offset= -0.025677538
# iteration #: 0038 cost= 0.020804336 size_factor= 0.9563038 price_offset= -0.02095472
# iteration #: 0040 cost= 0.020638786 size_factor= 0.96069014 price_offset= -0.017088648
# iteration #: 0042 cost= 0.020528717 size_factor= 0.9642808 price_offset= -0.013923923
# iteration #: 0044 cost= 0.020455673 size_factor= 0.96721953 price_offset= -0.01133329
# iteration #: 0046 cost= 0.020407304 size_factor= 0.96962523 price_offset= -0.009212623
# iteration #: 0048 cost= 0.020375367 size_factor= 0.97159415 price_offset= -0.0074766623
# iteration #: 0050 cost= 0.020354357 size_factor= 0.97320557 price_offset= -0.006055611
# Optimization Finished!
# Trained cost= 0.020354357 size_factor= 0.97320557 price_offset= -0.006055611

# %%
# Launch the graph in the session
with tf.Session() as sess:
    sess.run(init)

    # set how often to display training progress and number of training iterations
    display_every = 2
    num_training_iter = 500

    # calculate the number of lines to animation
    fit_num_plots = math.floor(num_training_iter/display_every)
    # add storage of factor and offset values from each epoch
    fit_size_factor = np.zeros(fit_num_plots)
    fit_price_offsets = np.zeros(fit_num_plots)
    fit_plot_idx = 0    

   # keep iterating the training data
    for iteration in range(num_training_iter):

        # Fit all training data
        for (x, y) in zip(train_house_size_norm, train_price_norm):
            sess.run(optimizer, feed_dict={tf_house_size: x, tf_price: y})

        # Display current status
        if (iteration + 1) % display_every == 0:
            c = sess.run(tf_cost, feed_dict={tf_house_size: train_house_size_norm, tf_price:train_price_norm})
            print("iteration #:", '%04d' % (iteration + 1), "cost=", "{:.9f}".format(c), \
                "size_factor=", sess.run(tf_size_factor), "price_offset=", sess.run(tf_price_offset))
            # Save the fit size_factor and price_offset to allow animation of learning process
            fit_size_factor[fit_plot_idx] = sess.run(tf_size_factor)
            fit_price_offsets[fit_plot_idx] = sess.run(tf_price_offset)
            fit_plot_idx = fit_plot_idx + 1

    print("Optimization Finished!")
    training_cost = sess.run(tf_cost, feed_dict={tf_house_size: train_house_size_norm, tf_price: train_price_norm})
    print("Trained cost=", training_cost, "size_factor=", sess.run(tf_size_factor), "price_offset=", sess.run(tf_price_offset), '\n')


   # Plot of training and test data, and learned regression
    
    # get values used to normalized data so we can denormalize data back to its original scale
    train_house_size_mean = train_house_size.mean()
    train_house_size_std = train_house_size.std()

    train_price_mean = train_price.mean()
    train_price_std = train_price.std()

    # Plot the graph
    plt.rcParams["figure.figsize"] = (10,8)
    plt.figure()
    plt.ylabel("Price")
    plt.xlabel("Size (sq.ft)")
    plt.plot(train_house_size, train_price, 'go', label='Training data')
    plt.plot(test_house_size, test_house_price, 'mo', label='Testing data')
    plt.plot(train_house_size_norm * train_house_size_std + train_house_size_mean,
             (sess.run(tf_size_factor) * train_house_size_norm + sess.run(tf_price_offset)) * train_price_std + train_price_mean,
             label='Learned Regression')
 
    plt.legend(loc='upper left')
    plt.show()



    # 
    # Plot another graph that animation of how Gradient Descent sequentually adjusted size_factor and price_offset to 
    # find the values that returned the "best" fit line.
    fig, ax = plt.subplots()
    line, = ax.plot(house_size, house_price)

    plt.rcParams["figure.figsize"] = (10,8)
    plt.title("Gradient Descent Fitting Regression Line")
    plt.ylabel("Price")
    plt.xlabel("Size (sq.ft)")
    plt.plot(train_house_size, train_price, 'go', label='Training data')
    plt.plot(test_house_size, test_house_price, 'mo', label='Testing data')

    def animate(i):
        line.set_xdata(train_house_size_norm * train_house_size_std + train_house_size_mean)  # update the data
        line.set_ydata((fit_size_factor[i] * train_house_size_norm + fit_price_offsets[i]) * train_price_std + train_price_mean)  # update the data
        return line,
 
     # Init only required for blitting to give a clean slate.
    def initAnim():
        line.set_ydata(np.zeros(shape=house_price.shape[0])) # set y's to 0
        return line,

    ani = animation.FuncAnimation(fig, animate, frames=np.arange(0, fit_plot_idx), init_func=initAnim,
                                 interval=1000, blit=True)

    plt.show()
# Out:
# iteration #: 0002 cost= 0.720058978 size_factor= 0.09177997 price_offset= -0.78197587
# iteration #: 0004 cost= 0.488989919 size_factor= 0.25305912 price_offset= -0.6400547
# iteration #: 0006 cost= 0.334198892 size_factor= 0.38506958 price_offset= -0.52387947
# iteration #: 0008 cost= 0.230510592 size_factor= 0.4931228 price_offset= -0.42877954
# iteration #: 0010 cost= 0.161057383 size_factor= 0.5815667 price_offset= -0.35093102
# iteration #: 0012 cost= 0.114538930 size_factor= 0.65396035 price_offset= -0.2872049
# iteration #: 0014 cost= 0.083384469 size_factor= 0.713216 price_offset= -0.23503916
# iteration #: 0016 cost= 0.062521778 size_factor= 0.76171756 price_offset= -0.19233663
# iteration #: 0018 cost= 0.048552584 size_factor= 0.8014175 price_offset= -0.1573807
# iteration #: 0020 cost= 0.039200630 size_factor= 0.8339127 price_offset= -0.1287661
# iteration #: 0022 cost= 0.032940891 size_factor= 0.86051065 price_offset= -0.10534229
# iteration #: 0024 cost= 0.028751854 size_factor= 0.882282 price_offset= -0.08616769
# iteration #: 0026 cost= 0.025949381 size_factor= 0.90010184 price_offset= -0.07047155
# iteration #: 0028 cost= 0.024075124 size_factor= 0.9146879 price_offset= -0.05762279
# iteration #: 0030 cost= 0.022822181 size_factor= 0.92662656 price_offset= -0.04710484
# iteration #: 0032 cost= 0.021984996 size_factor= 0.9363989 price_offset= -0.038494952
# iteration #: 0034 cost= 0.021425985 size_factor= 0.9443974 price_offset= -0.031446975
# iteration #: 0036 cost= 0.021052983 size_factor= 0.9509445 price_offset= -0.025677538
# iteration #: 0038 cost= 0.020804336 size_factor= 0.9563038 price_offset= -0.02095472
# iteration #: 0040 cost= 0.020638786 size_factor= 0.96069014 price_offset= -0.017088648
# iteration #: 0042 cost= 0.020528717 size_factor= 0.9642808 price_offset= -0.013923923
# iteration #: 0044 cost= 0.020455673 size_factor= 0.96721953 price_offset= -0.01133329
# iteration #: 0046 cost= 0.020407304 size_factor= 0.96962523 price_offset= -0.009212623
# iteration #: 0048 cost= 0.020375367 size_factor= 0.97159415 price_offset= -0.0074766623
# iteration #: 0050 cost= 0.020354357 size_factor= 0.97320557 price_offset= -0.006055611
# iteration #: 0052 cost= 0.020340588 size_factor= 0.97452503 price_offset= -0.0048923492
# iteration #: 0054 cost= 0.020331621 size_factor= 0.975605 price_offset= -0.0039401096
# iteration #: 0056 cost= 0.020325828 size_factor= 0.9764892 price_offset= -0.0031606166
# iteration #: 0058 cost= 0.020322114 size_factor= 0.9772123 price_offset= -0.002522529
# iteration #: 0060 cost= 0.020319769 size_factor= 0.9778048 price_offset= -0.002000194
# iteration #: 0062 cost= 0.020318314 size_factor= 0.97828937 price_offset= -0.001572617
# iteration #: 0064 cost= 0.020317435 size_factor= 0.9786863 price_offset= -0.0012226024
# iteration #: 0066 cost= 0.020316925 size_factor= 0.9790108 price_offset= -0.0009360824
# iteration #: 0068 cost= 0.020316642 size_factor= 0.9792765 price_offset= -0.0007015415
# iteration #: 0070 cost= 0.020316510 size_factor= 0.9794939 price_offset= -0.00050954736
# iteration #: 0072 cost= 0.020316459 size_factor= 0.97967196 price_offset= -0.0003523823
# iteration #: 0074 cost= 0.020316465 size_factor= 0.9798177 price_offset= -0.00022372848
# iteration #: 0076 cost= 0.020316495 size_factor= 0.9799371 price_offset= -0.00011841328
# iteration #: 0078 cost= 0.020316537 size_factor= 0.98003477 price_offset= -3.220212e-05
# iteration #: 0080 cost= 0.020316586 size_factor= 0.9801145 price_offset= 3.837017e-05
# iteration #: 0082 cost= 0.020316631 size_factor= 0.98017955 price_offset= 9.61389e-05
# iteration #: 0084 cost= 0.020316679 size_factor= 0.980233 price_offset= 0.00014342867
# iteration #: 0086 cost= 0.020316720 size_factor= 0.9802769 price_offset= 0.00018213899
# iteration #: 0088 cost= 0.020316755 size_factor= 0.9803127 price_offset= 0.0002138276
# iteration #: 0090 cost= 0.020316785 size_factor= 0.9803422 price_offset= 0.00023976703
# iteration #: 0092 cost= 0.020316813 size_factor= 0.98036647 price_offset= 0.00026100053
# iteration #: 0094 cost= 0.020316835 size_factor= 0.9803862 price_offset= 0.000278383
# iteration #: 0096 cost= 0.020316854 size_factor= 0.9804024 price_offset= 0.0002926123
# iteration #: 0098 cost= 0.020316867 size_factor= 0.9804158 price_offset= 0.00030425997
# iteration #: 0100 cost= 0.020316882 size_factor= 0.98042685 price_offset= 0.00031379508
# iteration #: 0102 cost= 0.020316895 size_factor= 0.9804359 price_offset= 0.00032160032
# iteration #: 0104 cost= 0.020316904 size_factor= 0.9804437 price_offset= 0.00032798995
# iteration #: 0106 cost= 0.020316910 size_factor= 0.98044956 price_offset= 0.0003332197
# iteration #: 0108 cost= 0.020316917 size_factor= 0.9804541 price_offset= 0.00033750242
# iteration #: 0110 cost= 0.020316921 size_factor= 0.980458 price_offset= 0.00034100693
# iteration #: 0112 cost= 0.020316929 size_factor= 0.9804613 price_offset= 0.00034387657
# iteration #: 0114 cost= 0.020316927 size_factor= 0.9804639 price_offset= 0.00034622522
# iteration #: 0116 cost= 0.020316929 size_factor= 0.98046625 price_offset= 0.00034814837
# iteration #: 0118 cost= 0.020316936 size_factor= 0.9804681 price_offset= 0.00034972178
# iteration #: 0120 cost= 0.020316938 size_factor= 0.9804696 price_offset= 0.00035100942
# iteration #: 0122 cost= 0.020316938 size_factor= 0.98047066 price_offset= 0.00035206313
# iteration #: 0124 cost= 0.020316942 size_factor= 0.9804715 price_offset= 0.0003529248
# iteration #: 0126 cost= 0.020316942 size_factor= 0.9804723 price_offset= 0.00035363142
# iteration #: 0128 cost= 0.020316942 size_factor= 0.98047304 price_offset= 0.00035420927
# iteration #: 0130 cost= 0.020316942 size_factor= 0.98047376 price_offset= 0.0003546817
# iteration #: 0132 cost= 0.020316944 size_factor= 0.98047435 price_offset= 0.00035506868
# iteration #: 0134 cost= 0.020316944 size_factor= 0.9804748 price_offset= 0.00035538647
# iteration #: 0136 cost= 0.020316944 size_factor= 0.9804753 price_offset= 0.000355646
# iteration #: 0138 cost= 0.020316944 size_factor= 0.9804756 price_offset= 0.00035585847
# iteration #: 0140 cost= 0.020316947 size_factor= 0.98047584 price_offset= 0.00035603245
# iteration #: 0142 cost= 0.020316947 size_factor= 0.980476 price_offset= 0.00035617454
# iteration #: 0144 cost= 0.020316947 size_factor= 0.98047614 price_offset= 0.000356291
# iteration #: 0146 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035638738
# iteration #: 0148 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.0003564649
# iteration #: 0150 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035652771
# iteration #: 0152 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035658013
# iteration #: 0154 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035662242
# iteration #: 0156 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.0003566563
# iteration #: 0158 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035668543
# iteration #: 0160 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035670892
# iteration #: 0162 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035672772
# iteration #: 0164 cost= 0.020316947 size_factor= 0.98047626 price_offset= 0.00035674288
# iteration #: 0166 cost= 0.020316947 size_factor= 0.9804763 price_offset= 0.00035675536
# iteration #: 0168 cost= 0.020316947 size_factor= 0.9804763 price_offset= 0.00035676608
# iteration #: 0170 cost= 0.020316947 size_factor= 0.9804763 price_offset= 0.00035677513
# iteration #: 0172 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.0003567833
# iteration #: 0174 cost= 0.020316942 size_factor= 0.9804763 price_offset= 0.00035679023
# iteration #: 0176 cost= 0.020316942 size_factor= 0.9804763 price_offset= 0.00035679646
# iteration #: 0178 cost= 0.020316942 size_factor= 0.9804763 price_offset= 0.00035680144
# iteration #: 0180 cost= 0.020316942 size_factor= 0.9804763 price_offset= 0.0003568053
# iteration #: 0182 cost= 0.020316942 size_factor= 0.9804763 price_offset= 0.00035680813
# iteration #: 0184 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035680993
# iteration #: 0186 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.0003568113
# iteration #: 0188 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681258
# iteration #: 0190 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681357
# iteration #: 0192 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681445
# iteration #: 0194 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681538
# iteration #: 0196 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681602
# iteration #: 0198 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681648
# iteration #: 0200 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681672
# iteration #: 0202 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681695
# iteration #: 0204 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681718
# iteration #: 0206 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.0003568174
# iteration #: 0208 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681765
# iteration #: 0210 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.00035681782
# iteration #: 0212 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0214 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0216 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0218 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0220 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0222 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0224 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0226 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0228 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0230 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0232 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0234 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0236 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0238 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0240 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0242 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0244 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0246 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0248 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0250 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0252 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0254 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0256 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0258 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0260 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0262 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0264 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0266 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0268 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0270 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0272 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0274 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0276 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0278 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0280 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0282 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0284 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0286 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0288 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0290 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0292 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0294 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0296 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0298 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0300 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0302 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0304 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0306 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0308 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0310 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0312 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0314 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0316 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0318 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0320 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0322 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0324 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0326 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0328 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0330 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0332 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0334 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0336 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0338 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0340 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0342 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0344 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0346 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0348 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0350 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0352 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0354 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0356 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0358 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0360 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0362 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0364 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0366 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0368 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0370 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0372 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0374 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0376 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0378 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0380 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0382 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0384 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0386 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0388 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0390 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0392 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0394 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0396 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0398 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0400 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0402 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0404 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0406 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0408 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0410 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0412 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0414 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0416 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0418 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0420 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0422 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0424 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0426 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0428 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0430 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0432 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0434 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0436 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0438 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0440 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0442 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0444 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0446 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0448 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0450 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0452 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0454 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0456 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0458 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0460 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0462 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0464 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0466 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0468 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0470 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0472 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0474 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0476 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0478 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0480 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0482 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0484 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0486 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0488 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0490 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0492 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0494 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0496 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0498 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# iteration #: 0500 cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
# Optimization Finished!
# Trained cost= 0.020316944 size_factor= 0.9804763 price_offset= 0.000356818
